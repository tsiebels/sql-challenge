# %%
{
  "metadata": {
    "kernelspec": {
      "name": "snowflake",
      "display_name": "Snowflake"
    }
  },
  "nbformat_minor": 5,
  "nbformat": 4,
  "cells": [
    {
      "cell_type": "markdown",
      "id": "intro-header",
      "metadata": {
        "collapsed": false,
        "codeCollapsed": true
      },
      "source": "# Welcome to SQL Challenge 🎉\n**13 weeks · ~15 minutes a week · real data · instant feedback**\n\n---"
    },
    {
      "cell_type": "markdown",
      "id": "intro-what",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "## What is this?\n\nThis is a self-paced SQL upskilling challenge for the analytics team. Each week you'll get a short notebook like this one with a few tasks to complete. The tasks build on each other week by week, so by the end you'll have written a production-ready analytics script covering revenue, retention, funnels, and customer segmentation.\n\nThere's no pressure and no strict deadlines — the goal is to build good habits and get more comfortable writing SQL on real data. Each week is designed to take around 15 minutes.\n\nYou can re-submit any task as many times as you like. Only your highest score is kept."
    },
    {
      "id": "99bacc9d-b109-41d9-867c-e4bee2982f79",
      "cell_type": "markdown",
      "metadata": {
        "collapsed": false,
        "codeCollapsed": true
      },
      "source": "---\n\n## SQL Challenge Setup - My Workspace\n\nTo start the SQL Challenge, click on the elipses for the folder **SQL Challenge - Q2 2026.** Select **COPY TO** and then select **My Workspace.**\n\nYou will now find a copy of the SQL Challenge folder with the notebooks for each week in your workspace. You can work directly within the notebooks without overwriting the original copy."
    },
    {
      "cell_type": "markdown",
      "id": "intro-setup-desc",
      "metadata": {
        "codeCollapsed": true,
        "collapsed": false
      },
      "source": "---\n\n## Your Snowflake setup\n\nBefore you run any queries, make sure your worksheet is pointed at the right place. Run the cell below — it sets your database, schema, role, and warehouse all at once. **Do this at the start of every session.**"
    },
    {
      "cell_type": "code",
      "id": "intro-setup",
      "metadata": {
        "language": "sql",
        "resultVariableName": "dataframe_1"
      },
      "source": "%%sql -r dataframe_1\n-- Run this at the start of every session\nUSE ROLE      ANALYTICS_TEAM_ROLE;\nUSE WAREHOUSE ANALYTICS_TEAM_WH;\nUSE DATABASE  ANALYTICS_TEAM_DB;\nUSE SCHEMA    ANALYTICS_TEAM_DB.SQL_CHALLENGE;",
      "outputs": [],
      "execution_count": null
    },
    {
      "cell_type": "markdown",
      "id": "intro-setup-table",
      "metadata": {
        "collapsed": false,
        "codeCollapsed": true
      },
      "source": "Here's what each of those means:\n\n| Setting | Value | What it is |\n|---|---|---|\n| Role | `ANALYTICS_TEAM_ROLE` | Controls what you have permission to see and do |\n| Warehouse | `ANALYTICS_TEAM_WH` | The compute that runs your queries |\n| Database | `ANALYTICS_TEAM_DB` | The database that holds all the data |\n| Schema | `ANALYTICS_TEAM_DB.SQL_CHALLENGE` | Where the challenge dataset lives |"
    },
    {
      "cell_type": "markdown",
      "id": "intro-dataset-desc",
      "metadata": {
        "collapsed": false,
        "codeCollapsed": true
      },
      "source": "---\n\n## The dataset\n\nAll 13 weeks use the **Olist Brazilian E-Commerce** dataset. Olist is a Brazilian online marketplace that connects small merchants to customers across the country. The dataset covers around **100,000 real orders** placed between 2016 and 2018, and is one of the most popular real-world e-commerce datasets available.\n\nIt's a great dataset to learn on because it's messy in realistic ways — there are NULLs where you'd expect values, dates that don't line up, and product categories written in Portuguese. You'll deal with all of that as the weeks progress.\n\nThe dataset is split across 9 tables in the `ANALYTICS_TEAM_DB.SQL_CHALLENGE` schema:"
    },
    {
      "cell_type": "markdown",
      "id": "intro-tables",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "| Table | Rows (approx) | What it contains |\n|---|---|---|\n| `OLIST_ORDERS` | 99,441 | One row per order — status, timestamps, customer link |\n| `OLIST_CUSTOMERS` | 99,441 | Customer location and ID |\n| `OLIST_ORDER_ITEMS` | 112,650 | Line items — what was in each order, price, seller |\n| `OLIST_ORDER_PAYMENTS` | 103,886 | Payment method and value per order |\n| `OLIST_ORDER_REVIEWS` | 99,224 | Customer review scores and comments |\n| `OLIST_PRODUCTS` | 32,951 | Product details and category |\n| `OLIST_SELLERS` | 3,095 | Seller location and ID |\n| `OLIST_GEOLOCATION` | 1,000,163 | ZIP code lat/long mappings |\n| `PRODUCT_CATEGORY_NAME_TRANSLATION` | 71 | Portuguese → English category names |"
    },
    {
      "cell_type": "markdown",
      "id": "intro-schema-diagram",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "**How the tables connect:**\n\n```\nOLIST_CUSTOMERS\n      │ customer_id\n      ▼\nOLIST_ORDERS ──── order_id ────┬──── OLIST_ORDER_ITEMS ──── product_id ──── OLIST_PRODUCTS\n                               ├──── OLIST_ORDER_PAYMENTS                         │ category\n                               └──── OLIST_ORDER_REVIEWS        PRODUCT_CATEGORY_NAME_TRANSLATION\n                                           OLIST_ORDER_ITEMS ──── seller_id ──── OLIST_SELLERS\n```\n\nYou won't need all of these right away. The first three weeks use just `OLIST_ORDERS` and `OLIST_CUSTOMERS`. New tables are introduced gradually as the challenge progresses."
    },
    {
      "cell_type": "markdown",
      "id": "intro-verify-desc",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "---\n\n## Verify your access\n\nRun the cells below to confirm you can see the data. If any of these return an error, let the challenge organiser know."
    },
    {
      "cell_type": "code",
      "id": "intro-verify-tables",
      "metadata": {
        "language": "sql",
        "resultVariableName": "dataframe_2"
      },
      "source": "%%sql -r dataframe_2\n-- Check you can see the tables\nSHOW TABLES IN SCHEMA ANALYTICS_TEAM_DB.SQL_CHALLENGE;",
      "outputs": [],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "id": "intro-verify-count",
      "metadata": {
        "language": "sql",
        "resultVariableName": "dataframe_3"
      },
      "source": "%%sql -r dataframe_3\n-- Check you can query the main orders table\nSELECT COUNT(*) AS total_orders\nFROM ANALYTICS_TEAM_DB.SQL_CHALLENGE.OLIST_ORDERS;",
      "outputs": [],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "id": "intro-verify-submit",
      "metadata": {
        "language": "sql",
        "resultVariableName": "dataframe_4"
      },
      "source": "%%sql -r dataframe_4\n-- Check the submission procedure is accessible\nCALL ANALYTICS_TEAM_DB.SQL_CHALLENGE.SUBMIT('test', 0, 0, $$ SELECT 1 AS test $$);",
      "outputs": [],
      "execution_count": null
    },
    {
      "cell_type": "markdown",
      "id": "intro-verify-ok",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "If the last cell returns a score result (even 0/0 for week 0) you're all set. ✅"
    },
    {
      "cell_type": "markdown",
      "id": "intro-submitting",
      "metadata": {
        "collapsed": false,
        "codeCollapsed": true
      },
      "source": "---\n\n## How submitting works\n\nAt the end of each week's notebook you'll find a submit cell for each task. It looks like this:\n\n```sql\nCALL ANALYTICS_TEAM_DB.SQL_CHALLENGE.SUBMIT(\n    CURRENT_USER(),  -- use the same name every week\n    1,               -- week number\n    1,               -- task number\n    $$\n        -- paste your query here\n        SELECT ...\n    $$\n);\n```\n\nYou submit once per task. The results pane will immediately show your score and a hint for anything that didn't pass. Re-submit as many times as you like — only your best score per task is saved.\n\n> **Important:** Exclude the semi-colon at the end of your query in the stored proc. Also, remove comment lines or the procedure will fail.\n\n> **Note:** Click on the result that outputs and it should open a side bar that makes the feedback JSON more readable."
    },
    {
      "cell_type": "markdown",
      "id": "intro-plan",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "---\n\n## The 13-week plan\n\n| Week | Topic | New tables introduced |\n|---|---|---|\n| 1 | SELECT, WHERE, ORDER BY | `OLIST_ORDERS` |\n| 2 | GROUP BY, COUNT, SUM | `OLIST_ORDERS` |\n| 3 | JOINs | `OLIST_CUSTOMERS` |\n| 4 | Subqueries and CTEs | `OLIST_ORDER_ITEMS`, `OLIST_ORDER_PAYMENTS` |\n| 5 | Window functions — ROW_NUMBER, RANK, QUALIFY | — |\n| 6 | LAG, LEAD, running totals | — |\n| 7 | Cohort analysis and retention | `OLIST_ORDER_REVIEWS` |\n| 8 | Funnel analysis and conversion rates | `OLIST_PRODUCTS`, `OLIST_SELLERS` |\n| 9 | RFM customer segmentation | — |\n| 10 | Data quality, NULLs, deduplication | `OLIST_GEOLOCATION` |\n| 11 | Query performance and Snowflake QUERY_HISTORY | — |\n| 12 | Combining all layers into one script | `PRODUCT_CATEGORY_NAME_TRANSLATION` |\n| 13 | Capstone — end-to-end analytics script | All tables |"
    },
    {
      "cell_type": "markdown",
      "id": "intro-footer",
      "metadata": {
        "codeCollapsed": true
      },
      "source": "---\n\nGood luck — and remember, the point isn't to get everything right first time. It's to get curious, try things, and learn from what comes back. See you in Week 1! 🚀"
    }
  ]
}
